# %% [markdown]
# ### 1. Carga de Datos y Exploración Inicial
#
# - Importa las librerías necesarias para el análisis de datos.
# - Carga todos los datasets desde la carpeta datasets/.
# - Muestra las primeras filas de cada dataset para una exploración inicial.

# %%
# Instalar las librerías necesarias
# !pip install pandas numpy matplotlib

# Importar las librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Configuración opcional para visualizar todas las columnas
pd.set_option('display.max_columns', None)

# Definir la ruta a la carpeta de datasets
data_path = '../'

# Cargar los datasets crudos
grupos = pd.read_csv(data_path + 'grupos.csv')
ubicaciones = pd.read_csv(data_path + 'ubicaciones.csv')
caracteristicas = pd.read_csv(data_path + 'caracteristicas.csv')
recursos_caracteristicas = pd.read_csv(data_path + 'recursos_caracteristicas.csv')
franjas_media_hora = pd.read_csv(data_path + 'franjas_media_hora.csv')
franjas_cuarto_hora = pd.read_csv(data_path + 'franjas_cuarto_hora.csv')
calendario_grupos = pd.read_csv(data_path + 'calendario_grupos.csv')

# Visualizar las primeras filas de cada dataset
print("Grupos:")
display(grupos.head())

print("Ubicaciones:")
display(ubicaciones.head())

print("Características:")
display(caracteristicas.head())

print("Recursos Características:")
display(recursos_caracteristicas.head())

print("Franjas Media Hora:")
display(franjas_media_hora.head())

print("Franjas Cuarto Hora:")
display(franjas_cuarto_hora.head())

print("Calendario Grupos:")
display(calendario_grupos.head())
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_19544\2709896188.py:13: DtypeWarning: Columns (13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   grupos = pd.read_csv(data_path + 'grupos.csv')
# Grupos:
#                    ID_GRUPO  ID_CURSO_ACADEMICO  ID_SEMESTRE  \
# 0  2024-0-102-106688-75-104                2024            0
# 1  2024-0-102-106688-75-118                2024            0
# 2  2024-0-102-106688-75-119                2024            0
# 3  2024-0-102-106688-75-121                2024            0
# 4  2024-0-102-106105-56-101                2024            0
#
#    ID_CENTRO_DEPART  ID_ASIGNATURA  ID_TIPO_DOCENCIA  ID_COD_GRUPO  \
# 0               102         106688                75           104
# 1               102         106688                75           118
# 2               102         106688                75           119
# 3               102         106688                75           121
# ...

# %% [markdown]
# ### 2. Exploración de Datos y Estadísticas Básicas
#
# - Utiliza el método .info() para obtener información sobre los tipos de datos y valores nulos en los datasets.
# - Genera estadísticas descriptivas utilizando .describe().
# - Visualiza la distribución del número de estudiantes por grupo y la capacidad de las aulas mediante histogramas.

# %%
# Verificar las columnas disponibles
print("Columnas en grupos:")
print(grupos.columns.tolist())
print("\nColumnas en ubicaciones:")
print(ubicaciones.columns.tolist())

# Exploración de los grupos
print("Información del dataset 'grupos':")
grupos.info()
print("\nDescripción estadística de 'grupos':")
display(grupos.describe())

# Distribución del número de estudiantes por grupo
plt.figure(figsize=(10,6))
plt.hist(grupos['IND_ALUMNOS_GRUPO_REAL'].dropna(), bins=20, edgecolor='k')
plt.xlabel('Número de Estudiantes')
plt.ylabel('Frecuencia')
plt.title('Distribución del Número de Estudiantes por Grupo')
plt.show()

# Exploración de las ubicaciones
print("Información del dataset 'ubicaciones':")
ubicaciones.info()
print("\nDescripción estadística de 'ubicaciones':")
display(ubicaciones.describe())

# Distribución de los metros de las ubicaciones
plt.figure(figsize=(10,6))
plt.hist(ubicaciones['IND_METRES'].dropna(), bins=20, edgecolor='k')
plt.xlabel('Metros cuadrados')
plt.ylabel('Frecuencia')
plt.title('Distribución de los Metros Cuadrados de las Ubicaciones')
plt.show()
# Out:
# Columnas en grupos:
# ['ID_GRUPO', 'ID_CURSO_ACADEMICO', 'ID_SEMESTRE', 'ID_CENTRO_DEPART', 'ID_ASIGNATURA', 'ID_TIPO_DOCENCIA', 'ID_COD_GRUPO', 'ID_PERIODO_DOCENTE', 'ID_VALOR_PERIODO_DOC', 'IND_ALUMNOS_GRUPO_PREV', 'IND_ALUMNOS_GRUPO_REAL', 'IND_HORAS_PREVISTAS', 'ID_UNIDAD_DOCENTE', 'ID_IDIOMA', 'ID_DEPARTAMENT_DELEG_DECODA', 'IDIOMA_MAJORITARI']
#
# Columnas en ubicaciones:
# ['ID_UBICACIO', 'DS_UBICACIO', 'ID_TIPUS_DEPENDENCIA', 'ID_EDIFICI', 'QL_PORTA', 'IND_METRES', 'ID_SN_BAIXA']
# Información del dataset 'grupos':
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515517 entries, 0 to 515516
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ID_GRUPO                     515517 non-null  object
#  1   ID_CURSO_ACADEMICO           515517 non-null  int64
#  2   ID_SEMESTRE                  515517 non-null  int64
# ...

# %% [markdown]
# ### 3. Identificación y Manejo de Valores Nulos
#
# - Identifica los valores nulos en los datasets grupos y ubicaciones.
# - Muestra cómo imputar valores faltantes utilizando otros campos o estadísticas (e.g., media).
# - Los participantes deben decidir la mejor estrategia de imputación según el contexto.

# %%
# Verificar valores nulos en 'grupos'
print("Valores nulos en 'grupos':")
print(grupos.isnull().sum())

# Imputar valores nulos en IND_ALUMNOS_GRUPO_REAL con IND_ALUMNOS_GRUPO_PREV
grupos['IND_ALUMNOS_GRUPO_REAL'].fillna(grupos['IND_ALUMNOS_GRUPO_PREV'], inplace=True)

# Verificar valores nulos en 'ubicaciones'
print("\nValores nulos en 'ubicaciones':")
print(ubicaciones.isnull().sum())

# Imputar valores nulos en 'IND_METRES' con la media
ubicaciones['IND_METRES'].fillna(ubicaciones['IND_METRES'].mean(), inplace=True)
# Out:
# Valores nulos en 'grupos':
# ID_GRUPO                       0
# ID_CURSO_ACADEMICO             0
# ID_SEMESTRE                    0
# ID_CENTRO_DEPART               0
# ID_ASIGNATURA                  0
# ID_TIPO_DOCENCIA               0
# ID_COD_GRUPO                   0
# ID_PERIODO_DOCENTE             0
# ID_VALOR_PERIODO_DOC           0
# IND_ALUMNOS_GRUPO_PREV         0
# IND_ALUMNOS_GRUPO_REAL         0
# IND_HORAS_PREVISTAS            0
# ID_UNIDAD_DOCENTE              0
# ID_IDIOMA                      0
# ID_DEPARTAMENT_DELEG_DECODA    0
# IDIOMA_MAJORITARI              0
# dtype: int64
#
# Valores nulos en 'ubicaciones':
# ID_UBICACIO             0
# DS_UBICACIO             0
# ID_TIPUS_DEPENDENCIA    0
# ID_EDIFICI              0
# QL_PORTA                1
# IND_METRES              1
# ID_SN_BAIXA             0
# dtype: int64
# ...

# %% [markdown]
# ### 4. Estandarización de Tipos de Datos
#
# - Asegura que los campos identificadores están en el tipo de datos correcto para facilitar las uniones.
# - Convierte campos de fecha al tipo datetime para permitir operaciones basadas en tiempo.
# - Los participantes deben manejar posibles errores o valores no convertibles.

# %%
# Asegurar que los identificadores clave son de tipo string
grupos['ID_GRUPO'] = grupos['ID_GRUPO'].astype(str)
ubicaciones['ID_UBICACIO'] = ubicaciones['ID_UBICACIO'].astype(str)
calendario_grupos['ID_GRUPO'] = calendario_grupos['ID_GRUPO'].astype(str)
calendario_grupos['ID_UBICACION'] = calendario_grupos['ID_UBICACION'].astype(str)

# Convertir fechas a formato datetime
calendario_grupos['ID_FECHA_GRUPO'] = pd.to_datetime(calendario_grupos['ID_FECHA_GRUPO'], errors='coerce')

# Verificar conversiones
print("\nTipos de datos en calendario_grupos:")
print(calendario_grupos.dtypes)
# Out:
# Tipos de datos en calendario_grupos:
# ID_ORIGEN                         object
# ID_GRUPO                          object
# ID_FECHA_GRUPO            datetime64[ns]
# ID_UBICACION                      object
# ID_HORA_INICIO                     int64
# ID_HORA_FIN                        int64
# ID_QUART_HORA                      int64
# IND_HORAS_CALENDARIO             float64
# ID_SESION                         object
# ID_CURSO_ACADEMICO                 int64
# ID_UBICACION_SAMAS                object
# IND_PCT_CLAU                       int64
# ID_CENTRE_COST                    object
# ID_UNITAT_COST                     int64
# ID_PROJECTE                        int64
# ID_CLAU_ACCES                      int64
# IND_METRES                       float64
# ID_RESPONSABLE_RESERVA            object
# ID_TIPO_RESERVA                    int64
# dtype: object

# %% [markdown]
# ### 5. Unión de Datasets
#
# - Muestra cómo unir los datasets clave para crear un conjunto de datos consolidado que permita el análisis.
# - Utiliza uniones left para conservar todos los registros de calendario_grupos y agregar información de otros datasets.
# - Los participantes deben verificar que las uniones sean correctas y manejar registros sin correspondencia.

# %%
# Unir 'calendario_grupos' con 'grupos' para obtener información sobre el número de estudiantes
calendario_completo = calendario_grupos.merge(
    grupos[['ID_GRUPO', 'IND_ALUMNOS_GRUPO_REAL']], 
    on='ID_GRUPO', 
    how='left'
)

# Unir con 'ubicaciones' para obtener información sobre las aulas
calendario_completo = calendario_completo.merge(
    ubicaciones[['ID_UBICACIO', 'IND_METRES']], 
    left_on='ID_UBICACION',
    right_on='ID_UBICACIO',
    how='left'
)

# Verificar el resultado
print("Calendario completo:")
display(calendario_completo.head())
# Out:
# Calendario completo:
#   ID_ORIGEN ID_GRUPO ID_FECHA_GRUPO ID_UBICACION  ID_HORA_INICIO  ID_HORA_FIN  \
# 0         G       -1     2025-09-30       GA/215            1130         1300
# 1         G       -1     2025-09-30       GA/215            1130         1300
# 2         G       -1     2025-09-30      LAU/305            1130         1430
# 3         G       -1     2025-09-30      LAU/305            1130         1430
# 4         G       -1     2025-09-30      LAU/305            1130         1430
#
#    ID_QUART_HORA  IND_HORAS_CALENDARIO ID_SESION  ID_CURSO_ACADEMICO  \
# 0             51                  0.25         M                2024
# 1             50                  0.25         M                2024
# 2             47                  0.25         M                2024
# 3             48                  0.25         M                2024
# 4             49                  0.25         M                2024
#
# ...

# %% [markdown]
# ### 6. Validación de Restricciones Básicas
#
# - Identifica casos donde el número de estudiantes excede la capacidad del aula.
# - Calcula el porcentaje de ocupación de cada clase.
# - Detecta posibles solapamientos de horarios en una misma aula.
# - Los participantes pueden profundizar en estas validaciones y corregir inconsistencias.

# %%
calendario_completo['CAPACIDAD_ESTIMADA'] = (calendario_completo['IND_METRES_y'] / 2).round()
calendario_completo['EXCEDE_CAPACIDAD'] = calendario_completo['IND_ALUMNOS_GRUPO_REAL'] > calendario_completo['CAPACIDAD_ESTIMADA']

# Mostrar los registros donde se excede la capacidad
excede_capacidad = calendario_completo[calendario_completo['EXCEDE_CAPACIDAD'] == True]
print("\nRegistros donde el número de estudiantes excede la capacidad estimada del aula:")
display(excede_capacidad)

# Calcular el porcentaje de ocupación
calendario_completo['PORCENTAJE_OCUPACION'] = (calendario_completo['IND_ALUMNOS_GRUPO_REAL'] / calendario_completo['CAPACIDAD_ESTIMADA'] * 100)

# Verificar solapamientos
solapamientos = calendario_completo.groupby(['ID_UBICACION', 'ID_FECHA_GRUPO', 'ID_QUART_HORA']).size().reset_index(name='CONTEO')
solapamientos = solapamientos[solapamientos['CONTEO'] > 1]
print("\nPosibles solapamientos de horarios en una misma aula:")
display(solapamientos)
# Out:
# Registros donde el número de estudiantes excede la capacidad estimada del aula:
#         ID_ORIGEN                  ID_GRUPO ID_FECHA_GRUPO ID_UBICACION  \
# 16190           P    2024-0-111-101985-69-1     2025-07-04           -1
# 16191           P    2024-0-111-101985-69-1     2025-07-04           -1
# 16192           P    2024-0-111-101985-69-1     2025-07-04           -1
# 16193           P    2024-0-111-101985-69-1     2025-07-04           -1
# 16254           P    2024-0-111-102034-69-1     2025-07-04           -1
# ...           ...                       ...            ...          ...
# 1047990         P     2024-0-111-101642-1-1     2024-12-09           -1
# 1047991         P  2024-0-111-102036-55-413     2024-12-09           -1
# 1047992         P  2024-0-111-102036-55-413     2024-12-09           -1
# 1047993         P  2024-0-111-102036-55-413     2024-12-09           -1
# 1047994         P  2024-0-111-102036-55-413     2024-12-09           -1
#
# ...

# %% [markdown]
# ### 7. Visualización de Ocupación por Franja Horaria
#
# - Calcula la ocupación media de estudiantes por franja horaria.
# - Genera un gráfico de barras para visualizar los horarios con mayor y menor ocupación.
# - Utiliza esta información para identificar patrones temporales

# %%
# Calcular la ocupación media por franja horaria
ocupacion_franja = calendario_completo.groupby('ID_QUART_HORA')['IND_ALUMNOS_GRUPO_REAL'].mean().reset_index()

# Ordenar por ID_QUART_HORA para una mejor visualización
ocupacion_franja = ocupacion_franja.sort_values('ID_QUART_HORA')

# Visualizar la ocupación media por franja horaria
plt.figure(figsize=(12,6))
plt.bar(ocupacion_franja['ID_QUART_HORA'], ocupacion_franja['IND_ALUMNOS_GRUPO_REAL'], color='skyblue')
plt.xlabel('ID Cuarto de Hora')
plt.ylabel('Ocupación Media de Estudiantes')
plt.title('Ocupación Media por Franja Horaria')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Opcional: Mostrar los valores numéricos
print("\nOcupación media por franja horaria:")
display(ocupacion_franja)
# Out:
# Ocupación media por franja horaria:
#     ID_QUART_HORA  IND_ALUMNOS_GRUPO_REAL
# 0              33                3.782490
# 1              34                3.915906
# 2              35               24.987131
# 3              36               25.019838
# 4              37               28.403424
# 5              38               28.485729
# 6              39               28.464708
# 7              40               28.513457
# 8              41               26.582525
# 9              42               27.437072
# 10             43               27.034475
# 11             44               26.967212
# 12             45               24.824545
# 13             46               26.783689
# 14             47               27.275319
# 15             48               26.388088
# 16             49               27.029189
# 17             50               27.043612
# 18             51               26.728302
# 19             52               26.630688
# ...

# %% [markdown]
# ### 8. Preparación para la Optimización
#
# - Prepara el dataset para la etapa de optimización, filtrando registros válidos.
# - Guarda el dataset procesado para ser utilizado en modelos o algoritmos de optimización.
# - Amplia este paso según sus necesidades.

# %%
# Filtrar las asignaciones válidas (sin exceder capacidad y sin valores nulos críticos)
calendario_valido = calendario_completo[
    (calendario_completo['EXCEDE_CAPACIDAD'] == False) &
    (calendario_completo['IND_ALUMNOS_GRUPO_REAL'].notnull()) &
    (calendario_completo['CAPACIDAD_ESTIMADA'].notnull())
]

# Guardar el dataset procesado para uso posterior
calendario_valido.to_csv('calendario_procesado.csv', index=False)

print("Dataset procesado y listo para la optimización.")
print(f"Registros originales: {len(calendario_completo)}")
print(f"Registros válidos: {len(calendario_valido)}")
# Out:
# Dataset procesado y listo para la optimización.
# Registros originales: 1048001
# Registros válidos: 540090

# %% [markdown]
# ### 9. Sugerencias para la Optimización
#
# Aunque la implementación de algoritmos de optimización queda a criterio de los participantes, aquí hay algunas sugerencias:
#
# - Definir el objetivo (e.g., minimizar el número de aulas utilizadas, minimizar el consumo energético).
# - Establecer las restricciones (e.g., capacidades, horarios, características de aulas).
#
# Herramientas y Librerías:
#
# - Utilizar librerías como PuLP o Pyomo para programación lineal y entera.
# - Considerar algoritmos heurísticos si el problema es complejo.
# - Ejemplo de Definición de Variables (usando PuLP):

# %%
# !pip install pulp

from pulp import LpProblem, LpVariable, LpMinimize, LpBinary, lpSum

# Crear el problema de optimización
prob = LpProblem("Optimización de Aulas", LpMinimize)

# Definir variables de decisión, por ejemplo:
# x[i,j] = 1 si el grupo i se asigna al aula j, 0 en caso contrario
# Crear un diccionario de variables binarias
x = LpVariable.dicts("asignacion", [(i,j) for i in grupos['ID_GRUPO'] for j in ubicaciones['ID_UBICACIO']], cat='Binary')

# Definir la función objetivo y las restricciones...

# %% [markdown]
# ### Recursos Adicionales
# Documentación de Librerías:
#
# - Pandas Documentation: https://pandas.pydata.org/
# - Matplotlib Documentation: https://matplotlib.org/
# - PuLP Documentation: https://coin-or.github.io/pulp/
# - Pyomo Documentation: https://www.pyomo.org/
#
# Tutoriales Útiles:
#
# - Introduction to Linear Programming in Python (ROOKIES): https://github.com/benalexkeen/Introduction-to-linear-programming
# - Análsiis de Datos con Python (ROOKIES): https://www.youtube.com/watch?v=TcdKDmtKeRY
# - Data Cleaning with Pandas: https://www.w3schools.com/python/pandas/default.asp
# - Hands-On Linear Programming: Optimization With Python: https://realpython.com/linear-programming-python/
#
# NOTAS:
#
# - Los ejemplos proporcionados son básicos y pueden requerir ajustes según la estructura específica de los datos.
# - Adapta el código a tus necesidades y profundiza en las áreas que consideres relevantes.
# - Te recomiendo que documentes el proceso, decisiones y hallazgos.
# - La claridad en la presentación de resultados y metodología será valorada.
